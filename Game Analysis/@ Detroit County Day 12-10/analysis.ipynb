# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("DCD.csv")
data
# Out:
#   PHS @ DCDS — All Athletes — Averages Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 0                                Games         GP           0       eFG%
# 1                              Overall          1           0     51.90%
# 2                                    0          0           0          0
# 3                            By Period         GP           0       eFG%
# 4                                  1st          1           0     41.20%
# 5                                  2nd          1           0     55.60%
# 6                                  3rd          1           0     53.80%
# 7                                  4th          1           0     60.00%
# 8                                  OT1          1           0     66.70%
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9  ...  \
# 0        TO%      OREB%      DREB%        FTF        VPS           0  ...
# 1     21.60%     44.80%     69.70%       0.54       1.07           0  ...
# ...
