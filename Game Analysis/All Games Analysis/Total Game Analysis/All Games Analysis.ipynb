# %%
import pandas as pd
import matplotlib.pyplot as plt

DCD = pd.read_csv("DCD_game_data.csv")
Novi = pd.read_csv("Novi_game_data.csv")
Pioneer = pd.read_csv("Pioneer_game_data.csv")
Rochester = pd.read_csv("Rochester_game_data.csv")
SLE = pd.read_csv("SLE_game_data.csv")
Summit = pd.read_csv("Summit_game_data.csv")

# %%
Games = pd.concat([Summit, SLE, Pioneer, DCD, Rochester, Novi])
Games.index = range(1, (len(Games)+1))
Games.rename(columns = {"Period": "Opponent"}, inplace = True)
Games
# Out:
#     Opponent    eFG%     TO%   OREB%   DREB%   FTF   VPS  FGM  FGA     FG%  \
# 1     Summit  53.00%  46.80%  36.40%  57.50%  0.36  0.61   15   33  45.50%
# 2        SLE  47.70%  20.20%  51.40%  73.70%  0.23  1.20   29   64  45.30%
# 3    Pioneer  47.20%  20.90%  36.70%  73.30%  0.41  1.02   23   54  42.60%
# 4        DCD  51.90%  21.60%  44.80%  69.70%  0.54  1.07   25   52  48.10%
# 5  Rochester  52.00%  14.30%  34.50%  75.00%  0.37  0.99   25   51  49.00%
# 6       Novi  46.30%  19.50%  32.30%  58.30%  0.15  0.77   23   54  42.60%
#
#    ...   SLOB%  PPSLOB  BLOB   BLOB%  PPBLOB  DEFL STL  BLK  FOUL CHG
# 1  ...  25.00%    0.50     6   0.00%    0.00     6   4    1    16   0
# 2  ...  80.00%    1.20     5  40.00%    0.80    14  11    0    13   2
# 3  ...  20.00%    0.40    10  20.00%    0.30    13   7    2    13   2
# 4  ...  40.00%    0.60     7  57.10%    1.29    17  11    1    21   0
# 5  ...  28.60%    0.71    11  36.40%    0.64     4  10    0    19   0
# 6  ...   0.00%    0.00     6  83.30%    1.50     5   4    2    19   0
#
# [6 rows x 50 columns]

# %%
Games = Games.drop(["OREB%.1", "DREB%.1", "eFG%.1", "TP", "PPG", "TO%.1", "SLOB%", "BLOB%", "CHG"], axis = 1)
Games
# Out:
#     Opponent    eFG%     TO%   OREB%   DREB%   FTF   VPS  FGM  FGA     FG%  \
# 1     Summit  53.00%  46.80%  36.40%  57.50%  0.36  0.61   15   33  45.50%
# 2        SLE  47.70%  20.20%  51.40%  73.70%  0.23  1.20   29   64  45.30%
# 3    Pioneer  47.20%  20.90%  36.70%  73.30%  0.41  1.02   23   54  42.60%
# 4        DCD  51.90%  21.60%  44.80%  69.70%  0.54  1.07   25   52  48.10%
# 5  Rochester  52.00%  14.30%  34.50%  75.00%  0.37  0.99   25   51  49.00%
# 6       Novi  46.30%  19.50%  32.30%  58.30%  0.15  0.77   23   54  42.60%
#
#    ...  TO  A/TO SLOB  PPSLOB  BLOB PPBLOB  DEFL  STL BLK  FOUL
# 1  ...  34  0.18    4    0.50     6   0.00     6    4   1    16
# 2  ...  18  0.33    5    1.20     5   0.80    14   11   0    13
# 3  ...  17  0.53    5    0.40    10   0.30    13    7   2    13
# 4  ...  18  0.50    5    0.60     7   1.29    17   11   1    21
# 5  ...  10  0.50    7    0.71    11   0.64     4   10   0    19
# 6  ...  14  0.50    1    0.00     6   1.50     5    4   2    19
#
# [6 rows x 41 columns]

# %%
# Games["OREB%"] = ((Games["OREB"] / Games["REB"]).round(2))
# Games["DREB%"] = ((Games["DREB"] / Games["REB"]).round(2))
Games["TO%"] = (((Games["TO"]*100) / (Games["FGA"] + Games["AST"] + Games["TO"] + (Games["FTA"] * 0.44)))/100).round(2)
Games["SLOBP"] = (Games["SLOB"] * Games["PPSLOB"]).round()
Games["BLOBP"] = (Games["BLOB"] * Games["PPBLOB"]).round()

# %%
Games["eFG%"] = (Games["eFG%"].str.replace('%', '').astype(float) / 100).round(2)
Games["FG%"] = (Games["FG%"].str.replace('%', '').astype(float) / 100).round(2)
Games["FT%"] = (Games["FT%"].str.replace('%', '').astype(float) / 100).round(2)
Games["2FG%"] = (Games["2FG%"].str.replace('%', '').astype(float) / 100).round(2)
Games["3FG%"] = (Games["3FG%"].str.replace('%', '').astype(float) / 100).round(2)
Games["OREB%"] = (Games["OREB%"].str.replace('%', '').astype(float) / 100).round(2)
Games["DREB%"] = (Games["DREB%"].str.replace('%', '').astype(float) / 100).round(2)
Games
# Out:
#     Opponent  eFG%   TO%  OREB%  DREB%   FTF   VPS  FGM  FGA   FG%  ...  SLOB  \
# 1     Summit  0.53  0.43   0.36   0.57  0.36  0.61   15   33  0.46  ...     4
# 2        SLE  0.48  0.19   0.51   0.74  0.23  1.20   29   64  0.45  ...     5
# 3    Pioneer  0.47  0.19   0.37   0.73  0.41  1.02   23   54  0.43  ...     5
# 4        DCD  0.52  0.20   0.45   0.70  0.54  1.07   25   52  0.48  ...     5
# 5  Rochester  0.52  0.13   0.34   0.75  0.37  0.99   25   51  0.49  ...     7
# 6       Novi  0.46  0.18   0.32   0.58  0.15  0.77   23   54  0.43  ...     1
#
#    PPSLOB  BLOB  PPBLOB  DEFL  STL  BLK  FOUL  SLOBP  BLOBP
# 1    0.50     6    0.00     6    4    1    16    2.0    0.0
# 2    1.20     5    0.80    14   11    0    13    6.0    4.0
# 3    0.40    10    0.30    13    7    2    13    2.0    3.0
# 4    0.60     7    1.29    17   11    1    21    3.0    9.0
# 5    0.71    11    0.64     4   10    0    19    5.0    7.0
# 6    0.00     6    1.50     5    4    2    19    0.0    9.0
#
# [6 rows x 43 columns]

# %%
Games = Games[["Opponent", "PF", "PA", "+/-", "FGM", "FGA", "FG%", "2FGM", "2FGA", "2FG%", "3FGM", "3FGA", "3FG%", "FTM", "FTA", "FT%", "OREB", "DREB", "REB", "AST", "TO", "A/TO", "DEFL", "STL", "BLK", "FOUL", "MINS", "PPP", "eFG%", "OREB%", "DREB%", "TO%", "PoT", "SCP", "PiP", "VPS", "FTF", "SLOB", "PPSLOB", "SLOBP", "BLOB", "PPBLOB", "BLOBP"]]

# %%
Games
# Out:
#     Opponent  PF  PA     +/-  FGM  FGA   FG%  2FGM  2FGA  2FG%  ...  SCP  PiP  \
# 1     Summit  36  78     -42   15   33  0.46    10    24  0.42  ...    4   20
# 2        SLE  75  57  + 18.0   29   64  0.45    26    51  0.51  ...   21   50
# 3    Pioneer  62  60   + 2.0   23   54  0.43    18    37  0.49  ...    9   32
# 4        DCD  73  67   + 6.0   25   52  0.48    21    38  0.55  ...   11   30
# 5  Rochester  63  54   + 9.0   25   51  0.49    22    38  0.58  ...    6   40
# 6       Novi  53  60      -7   23   54  0.43    19    42  0.45  ...   10   34
#
#     VPS   FTF  SLOB  PPSLOB  SLOBP  BLOB  PPBLOB  BLOBP
# 1  0.61  0.36     4    0.50    2.0     6    0.00    0.0
# 2  1.20  0.23     5    1.20    6.0     5    0.80    4.0
# 3  1.02  0.41     5    0.40    2.0    10    0.30    3.0
# 4  1.07  0.54     5    0.60    3.0     7    1.29    9.0
# 5  0.99  0.37     7    0.71    5.0    11    0.64    7.0
# 6  0.77  0.15     1    0.00    0.0     6    1.50    9.0
#
# [6 rows x 43 columns]

# %%
Basic = Games.iloc[:, :27]
Basic
# Out:
#     Opponent  PF  PA     +/-  FGM  FGA   FG%  2FGM  2FGA  2FG%  ...  DREB  \
# 1     Summit  36  78     -42   15   33  0.46    10    24  0.42  ...    23
# 2        SLE  75  57  + 18.0   29   64  0.45    26    51  0.51  ...    28
# 3    Pioneer  62  60   + 2.0   23   54  0.43    18    37  0.49  ...    22
# 4        DCD  73  67   + 6.0   25   52  0.48    21    38  0.55  ...    23
# 5  Rochester  63  54   + 9.0   25   51  0.49    22    38  0.58  ...    15
# 6       Novi  53  60      -7   23   54  0.43    19    42  0.45  ...    14
#
#    REB  AST  TO  A/TO  DEFL  STL  BLK  FOUL  MINS
# 1   31    6  34  0.18     6    4    1    16    32
# 2   46    6  18  0.33    14   11    0    13    34
# 3   33    9  17  0.53    13    7    2    13    34
# 4   36    9  18  0.50    17   11    1    21    37
# 5   25    5  10  0.50     4   10    0    19    34
# 6   24    7  14  0.50     5    4    2    19    34
#
# [6 rows x 27 columns]

# %%
Advanced = Games.iloc[:, 27:]
Advanced["Opponent"] = Games["Opponent"]
last = Advanced.iloc[:, -1]
Advanced = Advanced.drop(Advanced.columns[-1], axis =1)
Advanced.insert(0, last.name, last)
Advanced
# Out:
#     Opponent   PPP  eFG%  OREB%  DREB%   TO%  PoT  SCP  PiP   VPS   FTF  SLOB  \
# 1     Summit  0.56  0.53   0.36   0.57  0.43    4    4   20  0.61  0.36     4
# 2        SLE  1.05  0.48   0.51   0.74  0.19   24   21   50  1.20  0.23     5
# 3    Pioneer  0.88  0.47   0.37   0.73  0.19   11    9   32  1.02  0.41     5
# 4        DCD  1.04  0.52   0.45   0.70  0.20   19   11   30  1.07  0.54     5
# 5  Rochester  1.05  0.52   0.34   0.75  0.13   11    6   40  0.99  0.37     7
# 6       Novi  0.86  0.46   0.32   0.58  0.18   14   10   34  0.77  0.15     1
#
#    PPSLOB  SLOBP  BLOB  PPBLOB  BLOBP
# 1    0.50    2.0     6    0.00    0.0
# 2    1.20    6.0     5    0.80    4.0
# 3    0.40    2.0    10    0.30    3.0
# 4    0.60    3.0     7    1.29    9.0
# 5    0.71    5.0    11    0.64    7.0
# 6    0.00    0.0     6    1.50    9.0
