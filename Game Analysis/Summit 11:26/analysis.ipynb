# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("@ Summit.csv")
data
# Out:
#   PHS @ Summit Academy — All Athletes — Averages Unnamed: 1  Unnamed: 2  \
# 0                                          Games         GP           0
# 1                                        Overall          1           0
# 2                                              0          0           0
# 3                                      By Period         GP           0
# 4                                            1st          1           0
# 5                                            2nd          1           0
# 6                                            3rd          1           0
# 7                                            4th          1           0
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0       eFG%        TO%      OREB%      DREB%        FTF        VPS
# 1     53.00%     46.80%     36.40%     57.50%       0.36       0.61
# 2          0          0          0          0          0          0
# ...
