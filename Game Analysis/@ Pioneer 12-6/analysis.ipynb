# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("Pioneer.csv")
data
# Out:
#   PHS @ Pioneer — All Athletes — Averages Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 0                                   Games         GP           0       eFG%
# 1                                 Overall          1           0     47.20%
# 2                                       0          0           0          0
# 3                               By Period         GP           0       eFG%
# 4                                     1st          1           0     38.90%
# 5                                     2nd          1           0     58.30%
# 6                                     3rd          1           0     57.90%
# 7                                     4th          1           0     28.60%
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9  ...  \
# 0        TO%      OREB%      DREB%        FTF        VPS           0  ...
# 1     20.90%     36.70%     73.30%       0.41       1.02           0  ...
# 2          0          0          0          0          0           0  ...
# 3        TO%      OREB%      DREB%        FTF        VPS           0  ...
# 4     35.40%     37.50%     87.50%       0.89        0.7           0  ...
# 5     16.80%      0.00%     71.40%        0.5       1.03           0  ...
# 6      8.70%     40.00%     83.30%       0.21       1.58           0  ...
# 7     23.90%     40.00%     55.60%       0.29       0.92           0  ...
#
#   Unnamed: 52 Unnamed: 53 Unnamed: 54 Unnamed: 55  Unnamed: 56 Unnamed: 57  \
# 0      PPSLOB        BLOB       BLOB%      PPBLOB            0        DEFL
# 1         0.4          10      20.00%         0.3            0          13
# 2           0           0           0           0            0           0
# 3      PPSLOB        BLOB       BLOB%      PPBLOB            0        DEFL
# 4           0           5      20.00%         0.2            0           1
# 5           1           2       0.00%           0            0           4
# 6           0           0           -           0            0           2
# 7           0           3      33.30%        0.67            0           6
#
#   Unnamed: 58 Unnamed: 59  Unnamed: 60 Unnamed: 61
# 0         STL         BLK         FOUL         CHG
# 1           7           2           13           2
# 2           0           0            0           0
# 3         STL         BLK         FOUL         CHG
# 4           1           0            3           0
# 5           2           1            6           0
# 6           2           0            1           0
# 7           2           1            3           2
#
# [8 rows x 62 columns]

# %%
data.columns = data.iloc[0]
data.rename(columns = {"Games": "Period"}, inplace = True)
data = data.drop([0,2,3])
data.drop(["GP", 0.0], axis = 1, inplace = True)
data
# Out:
# 0   Period    eFG%     TO%   OREB%   DREB%   FTF   VPS FGM FGA     FG%  ...  \
# 1  Overall  47.20%  20.90%  36.70%  73.30%  0.41  1.02  23  54  42.60%  ...
# 4      1st  38.90%  35.40%  37.50%  87.50%  0.89   0.7   3   9  33.30%  ...
# 5      2nd  58.30%  16.80%   0.00%  71.40%   0.5  1.03   6  12  50.00%  ...
# 6      3rd  57.90%   8.70%  40.00%  83.30%  0.21  1.58  10  19  52.60%  ...
# 7      4th  28.60%  23.90%  40.00%  55.60%  0.29  0.92   4  14  28.60%  ...
#
# 0   SLOB% PPSLOB BLOB   BLOB% PPBLOB DEFL STL BLK FOUL CHG
# 1  20.00%    0.4   10  20.00%    0.3   13   7   2   13   2
# 4       -      0    5  20.00%    0.2    1   1   0    3   0
# 5  50.00%      1    2   0.00%      0    4   2   1    6   0
# 6   0.00%      0    0       -      0    2   2   0    1   0
# 7   0.00%      0    3  33.30%   0.67    6   2   1    3   2
#
# [5 rows x 50 columns]

# %%
game = data[:1].reset_index(drop = True)
quarters = data[1:].reset_index(drop = True)
quarters
# Out:
# 0 Period    eFG%     TO%   OREB%   DREB%   FTF   VPS FGM FGA     FG%  ...  \
# 0    1st  38.90%  35.40%  37.50%  87.50%  0.89   0.7   3   9  33.30%  ...
# 1    2nd  58.30%  16.80%   0.00%  71.40%   0.5  1.03   6  12  50.00%  ...
# 2    3rd  57.90%   8.70%  40.00%  83.30%  0.21  1.58  10  19  52.60%  ...
# 3    4th  28.60%  23.90%  40.00%  55.60%  0.29  0.92   4  14  28.60%  ...
#
# 0   SLOB% PPSLOB BLOB   BLOB% PPBLOB DEFL STL BLK FOUL CHG
# 0       -      0    5  20.00%    0.2    1   1   0    3   0
# 1  50.00%      1    2   0.00%      0    4   2   1    6   0
# 2   0.00%      0    0       -      0    2   2   0    1   0
# 3   0.00%      0    3  33.30%   0.67    6   2   1    3   2
#
# [4 rows x 50 columns]
