# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("SLE.csv")
data
# Out:
#   PHS vs SLEHS — All Athletes — Averages Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 0                                  Games         GP           0       eFG%
# 1                                Overall          1           0     47.70%
# 2                                      0          0           0          0
# 3                              By Period         GP           0       eFG%
# 4                                    1st          1           0     50.00%
# 5                                    2nd          1           0     40.60%
# 6                                    3rd          1           0     50.00%
# 7                                    4th          1           0     50.00%
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9  ...  \
# 0        TO%      OREB%      DREB%        FTF        VPS           0  ...
# 1     20.20%     51.40%     73.70%       0.23        1.2           0  ...
# ...

# %%
data.columns = data.iloc[0]
data.rename(columns = {"Games": "Period"}, inplace = True)
data = data.drop([0,2,3])
data.drop(["GP", 0.0], axis = 1, inplace = True)
data
# Out:
# 0   Period    eFG%     TO%   OREB%   DREB%   FTF   VPS FGM FGA     FG%  ...  \
# 1  Overall  47.70%  20.20%  51.40%  73.70%  0.23   1.2  29  64  45.30%  ...
# 4      1st  50.00%  25.10%  14.30%  80.00%  0.31  1.29   6  13  46.20%  ...
# 5      2nd  40.60%  19.50%  66.70%  57.10%  0.06     1   6  16  37.50%  ...
# 6      3rd  50.00%  18.20%  55.60%  75.00%     0  1.05   9  18  50.00%  ...
# 7      4th  50.00%  18.70%  60.00%  77.80%  0.59  1.43   8  17  47.10%  ...
#
# 0    SLOB% PPSLOB BLOB   BLOB% PPBLOB DEFL STL BLK FOUL CHG
# 1   80.00%    1.2    5  40.00%    0.8   14  11   0   13   2
# 4        -      0    2   0.00%      0    6   4   0    2   0
# 5  100.00%      2    3  66.70%   1.33    3   1   0    1   0
# 6    0.00%      0    0       -      0    1   2   0    6   1
# 7  100.00%   1.33    0       -      0    4   4   0    4   1
#
# [5 rows x 50 columns]

# %%
game = data[:1].reset_index(drop = True)
quarters = data[1:].reset_index(drop = True)
quarters
# Out:
# 0 Period    eFG%     TO%   OREB%   DREB%   FTF   VPS FGM FGA     FG%  ...  \
# 0    1st  50.00%  25.10%  14.30%  80.00%  0.31  1.29   6  13  46.20%  ...
# 1    2nd  40.60%  19.50%  66.70%  57.10%  0.06     1   6  16  37.50%  ...
# 2    3rd  50.00%  18.20%  55.60%  75.00%     0  1.05   9  18  50.00%  ...
# 3    4th  50.00%  18.70%  60.00%  77.80%  0.59  1.43   8  17  47.10%  ...
#
# 0    SLOB% PPSLOB BLOB   BLOB% PPBLOB DEFL STL BLK FOUL CHG
# 0        -      0    2   0.00%      0    6   4   0    2   0
# 1  100.00%      2    3  66.70%   1.33    3   1   0    1   0
# 2    0.00%      0    0       -      0    1   2   0    6   1
# 3  100.00%   1.33    0       -      0    4   4   0    4   1
#
# [4 rows x 50 columns]

# %%
# game.to_csv("SLE_game_data.csv", index = False)
# quarters.to_csv("SLE_quarters_data.csv", index = False)
