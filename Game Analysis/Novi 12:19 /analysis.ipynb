# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("Novi.csv")
data
# Out:
#   PHS vs Novi — All Athletes — Averages Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 0                                 Games         GP           0       eFG%
# 1                               Overall          1           0     46.30%
# 2                                     0          0           0          0
# 3                             By Period         GP           0       eFG%
# 4                                   1st          1           0     37.50%
# 5                                   2nd          1           0     46.70%
# 6                                   3rd          1           0     46.20%
# 7                                   4th          1           0     53.60%
#
#   Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9  ...  \
# 0        TO%      OREB%      DREB%        FTF        VPS           0  ...
# 1     19.50%     32.30%     58.30%       0.15       0.77           0  ...
# 2          0          0          0          0          0           0  ...
# ...
