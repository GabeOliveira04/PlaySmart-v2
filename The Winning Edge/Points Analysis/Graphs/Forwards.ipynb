# %%
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression               # Imported libraries
data = pd.read_csv("Regression Model Data +Tech - 2024 Draft Combine Stats (5).csv")
data.replace("-", pd.NA, inplace=True)
data["Shuttle Run"] = pd.to_numeric(data["Shuttle Run"])
data["Three Quarter Sprint"] = pd.to_numeric(data["Three Quarter Sprint"])      # Changed datatypes to numeric to proceed with analysis
data.head()
# Out:
#            PLAYER POS  Height  Weight  Wingspan  Standing Reach  Hand Length  \
# 0   Michael Ajayi  SF   77.75   227.8     84.75           106.5         9.50
# 1   Melvin Ajinca  SF   79.25   213.8     79.50           106.5         8.50
# 2  Trey Alexander  SG   75.25   187.0     82.50           101.5         8.75
# 3    Izan Almansa   C   81.25   219.6     85.00           110.0         9.25
# 4   Reece Beekman  PG   73.25   196.4     78.50           100.0         8.50
#
#    Hand Width  Lane Agility Time  Shuttle Run  Three Quarter Sprint  \
# 0        9.75              11.77         3.17                  3.21
# 1        9.75              11.78         3.00                  3.38
# 2       10.00              11.37         2.92                  3.21
# 3        9.25              10.94         2.96                  3.11
# 4        9.00              10.86         3.08                  2.94
#
#    Standing Vertical Leap  Max Vertical Leap   PPG  Free Throw %  \
# 0                    27.0               34.5  17.2          70.9
# 1                    26.5               31.0   9.3          79.7
# 2                    26.5               32.0  17.6          82.4
# 3                    28.0               35.0   8.2          37.9
# 4                    30.0               36.5  14.3          75.4
#
#   Three Point %  Two Point %   EFG
# 0            47         46.6  51.1
# 1          30.9         50.7  47.8
# 2          33.9         50.4  50.6
# 3          22.2         55.2  53.3
# 4            31         48.7  48.2

# %%
position_map = {
    "PG": "Guard", 
    "SG": "Guard",
    "PG-SG": "Guard",
    "SF": "Forward", 
    "PF": "Forward", 
    "C": "Center"
    }

data["POS"] = data["POS"].replace(position_map)         # Changed the format of the position to column to group players as Guards, Forwards, Centers
data.head()
# Out:
#            PLAYER      POS  Height  Weight  Wingspan  Standing Reach  \
# 0   Michael Ajayi  Forward   77.75   227.8     84.75           106.5
# 1   Melvin Ajinca  Forward   79.25   213.8     79.50           106.5
# 2  Trey Alexander    Guard   75.25   187.0     82.50           101.5
# 3    Izan Almansa   Center   81.25   219.6     85.00           110.0
# 4   Reece Beekman    Guard   73.25   196.4     78.50           100.0
#
#    Hand Length  Hand Width  Lane Agility Time  Shuttle Run  \
# 0         9.50        9.75              11.77         3.17
# 1         8.50        9.75              11.78         3.00
# 2         8.75       10.00              11.37         2.92
# 3         9.25        9.25              10.94         2.96
# 4         8.50        9.00              10.86         3.08
#
#    Three Quarter Sprint  Standing Vertical Leap  Max Vertical Leap   PPG  \
# 0                  3.21                    27.0               34.5  17.2
# 1                  3.38                    26.5               31.0   9.3
# 2                  3.21                    26.5               32.0  17.6
# 3                  3.11                    28.0               35.0   8.2
# 4                  2.94                    30.0               36.5  14.3
#
#    Free Throw % Three Point %  Two Point %   EFG
# 0          70.9            47         46.6  51.1
# 1          79.7          30.9         50.7  47.8
# 2          82.4          33.9         50.4  50.6
# 3          37.9          22.2         55.2  53.3
# 4          75.4            31         48.7  48.2

# %%
grouped = data["POS"].value_counts()
grouped
# Out:
# POS
# Forward    75
# Guard      72
# Center     27
# Name: count, dtype: int64

# %% [markdown]
# ### **All graphs below will compare the variables with Points Per Game for only Forwards**

# %%
forwards = data[data["POS"] == "Forward"]
plt.figure(figsize= (7,4))
x = forwards[["PPG"]]
y = forwards["Lane Agility Time"]
model = LinearRegression()
model.fit(x,y)
predictions = model.predict(x)
plt.scatter(x,y, color = "green")
plt.plot(x, predictions, color = "black")
plt.xlabel("Points Per Game")
plt.ylabel("Lane Agility Time")
plt.title("Points v Lane Agility Time")
plt.ylim(10.25,13)
plt.show()

# %%
data.dropna(subset=["Free Throw %", "Shuttle Run"], inplace = True)
forwards = data[data["POS"] == "Forward"]
plt.figure(figsize= (7,4))
x = forwards[["PPG"]]
y = forwards["Shuttle Run"]
model = LinearRegression()
model.fit(x,y)
predictions = model.predict(x)
plt.scatter(x,y, color = "green")
plt.plot(x, predictions, color = "black")
plt.xlabel("Points Per Game")
plt.ylabel("Shuttle Run")
plt.title("Points v Shuttle Run")
plt.ylim(2.75,3.75)
plt.show()

# %%
data.dropna(subset=["PPG", "Three Quarter Sprint"], inplace = True)
forwards = data[data["POS"] == "Forward"]
plt.figure(figsize= (7,4))
x = forwards[["PPG"]]
y = forwards["Three Quarter Sprint"]
model = LinearRegression()
model.fit(x,y)
predictions = model.predict(x)
plt.scatter(x,y, color = "green")
plt.plot(x, predictions, color = "black")
plt.xlabel("Points Per Game")
plt.ylabel("Three Quarter Sprint")
plt.title("Points v Three Quarter Sprint")
plt.ylim(2.75,3.75)
plt.show()

# %%
data.dropna(subset=["PPG", "Standing Vertical Leap"], inplace = True)
forwards = data[data["POS"] == "Forward"]
plt.figure(figsize= (7,4))
x = forwards[["PPG"]]
y = forwards["Standing Vertical Leap"]
model = LinearRegression()
model.fit(x,y)
predictions = model.predict(x)
plt.scatter(x,y, color = "green")
plt.plot(x, predictions, color = "black")
plt.xlabel("Points Per Game")
plt.ylabel("Standing Vert")
plt.title("Points v Standing Vert")
plt.ylim(20,45)
plt.show()

# %%
data.dropna(subset=["Free Throw %", "Max Vertical Leap"], inplace = True)
forwards = data[data["POS"] == "Forward"]
plt.figure(figsize= (7,4))
x = forwards[["PPG"]]
y = forwards["Max Vertical Leap"]
model = LinearRegression()
model.fit(x,y)
predictions = model.predict(x)
plt.scatter(x,y, color = "green")
plt.plot(x, predictions, color = "black")
plt.xlabel("Points Per Game")
plt.ylabel("Max Vert")
plt.title("Points v Max Vert")
plt.ylim(25,50)
plt.show()
